# %% [markdown]
# # Tarea 1
#
# ## Exploración de datos, PCA y regresión básica
#
# **Objetivo:** Utilizar conceptos estadísticos para entender la relación entre las variables de una base de
# datos. Adicionalmente, utilizar python como herramienta de exploración de datos y validación de
# hipótesis.

# %% [markdown]
# ### 1. Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
import csv
import random
import math
import scipy.spatial.distance as ssd
import scipy.cluster.hierarchy as sch
from sklearn.decomposition import PCA
import os
import math
import csv
import statistics

df_original = pd.read_csv('data.csv')
city_names = df_original["City"].values

# Remove categoric columns
df = df_original.drop(columns=['City','label', 'training'])

df_original
# Out:
#               City  GDP (USD Billion)  Population (Millions)  \
# 0           Bogotá              103.5                   7.18
# 1         Medellín               44.1                   2.57
# 2             Cali               22.4                   2.23
# 3     Barranquilla               16.8                   1.23
# 4        Cartagena               10.5                   1.03
# 5      Bucaramanga                7.3                   0.58
# 6          Pereira                6.2                   0.48
# 7           Cúcuta                5.1                   0.76
# 8           Ibagué                4.8                   0.53
# 9      Santa Marta                4.0                   0.52
# 10       Manizales                3.8                   0.43
# 11   Villavicencio                3.5                   0.50
# 12           Pasto                3.2                   0.45
# 13        Montería                3.0                   0.49
# ...

# %%
mean = df.mean().to_frame(name = "Mean")
mean
# Out:
#                             Mean
# GDP (USD Billion)       8.750000
# Population (Millions)   0.731000
# Unemployment rate (%)  13.833333
# Average age            29.233333
# Women (%)              51.500000
# Men (%)                48.500000
# Budget (USD Billion)    1.650000

# %%
median = df.median().to_frame(name = "Median")
median
# Out:
#                        Median
# GDP (USD Billion)        2.65
# Population (Millions)    0.39
# Unemployment rate (%)   13.45
# Average age             29.00
# Women (%)               51.00
# Men (%)                 49.00
# Budget (USD Billion)     0.60

# %%
std = df.std().to_frame(name = "Standard deviation")
std
# Out:
#                        Standard deviation
# GDP (USD Billion)               19.914433
# Population (Millions)            1.352832
# Unemployment rate (%)            2.945052
# Average age                      2.238893
# Women (%)                        0.776819
# Men (%)                          0.776819
# Budget (USD Billion)             3.451187

# %%
mode = df.mode().iloc[0].to_frame(name = "Mode")
mode
# Out:
#                         Mode
# GDP (USD Billion)       0.60
# Population (Millions)   0.01
# Unemployment rate (%)   9.20
# Average age            29.00
# Women (%)              51.00
# Men (%)                49.00
# Budget (USD Billion)    0.10

# %%
def get_repetitions(column):
    return column.value_counts()

repsMode = df.apply(get_repetitions).max().to_frame(name = "Mode repetitions")
repsMode
# Out:
#                        Mode repetitions
# GDP (USD Billion)                   1.0
# Population (Millions)               2.0
# Unemployment rate (%)               1.0
# Average age                         6.0
# Women (%)                          14.0
# Men (%)                            14.0
# Budget (USD Billion)                3.0

# %%
#Boxplots
fig, axs = plt.subplots(1, len(df.columns), figsize=(20,5))
for i, column in enumerate(df.columns):
    sns.boxplot(y=df[column], ax=axs[i])
    axs[i].set_title(column)
plt.tight_layout()
plt.show()

# %%
# Covariance matrix
cov_matrix = df.cov()
cov_matrix

# TODO : Calculate one by hand
# Out:
#                        GDP (USD Billion)  Population (Millions)  \
# GDP (USD Billion)             396.584655              26.685224
# Population (Millions)          26.685224               1.830154
# Unemployment rate (%)         -19.123103              -1.342793
# Average age                    15.087931               1.104931
# Women (%)                       4.243103               0.279138
# Men (%)                        -4.243103              -0.279138
# Budget (USD Billion)           68.613448               4.639603
#
#                        Unemployment rate (%)  Average age  Women (%)  \
# GDP (USD Billion)                 -19.123103    15.087931   4.243103
# Population (Millions)              -1.342793     1.104931   0.279138
# Unemployment rate (%)               8.673333    -5.232184  -0.993103
# Average age                        -5.232184     5.012644   1.224138
# Women (%)                          -0.993103     1.224138   0.603448
# ...

# %%
# Correlation
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".3f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation matrix heatmap")
plt.show()

# TODO : Calculate one by hand + Explain relation between cov and corr

# %% [markdown]
# #### K-Means (No libraries)

# %%
import math
import csv

k = 4
label_count = 4

with open('data.csv', 'r', newline='', encoding='utf-8') as file:
    reader = csv.reader(file)
    data = [row for row in reader]

train = [row for row in data if row[-1] == "Yes"]
test = [row for row in data if row[-1] == "No"]

label_row = data[0].index('label')

centroids = {}

def get_centroids():

    for i in range(0, label_count):
        centroids[i] = [0] * len(data[0])

    for current_label in range(0, label_count):
        filtered = [row for row in train if str(row[label_row]) == str(current_label)]
        for row in filtered:
            for i in range(0, len(row)):
                try:
                    centroids[current_label][i] += float(row[i])/len(filtered)
                except:
                    continue

def get_distance(centroid, row):
    distance = 0

    for i in range(0, len(centroid)):
        if (i != label_row):
            try:
                distance += abs(float(row[i]) - float(centroid[i])) ** 2
            except:
                continue

    return math.sqrt(distance)

def reassign_labels():
    swap = False

    for row in train:
        distances = []

        for l in range (0, label_count):
            distances.append(get_distance(centroids[l], row))

        min_dist = distances.index(min(distances))
        if row[label_row] != min_dist:
            row[label_row] = min_dist
            swap = True

    return swap

def perform_k_means():
    it = 0
    for i in range(0, k):
        it = i+1
        get_centroids()
        swap = reassign_labels()
        if not swap: break
    print("Iteration",it)

perform_k_means()

with open('k_means.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    for row in train:
        writer.writerow(row)

print("Training written to k_means.csv")

# Testing

def assign_closest_city():
    output = [["ID","label"]]

    for test_row in test:
        centroid_distances = {}

        for label in range(0, label_count):
            centroid_distances[label] = get_distance(centroids[label], test_row)

        closest_centroid = min(centroid_distances, key=centroid_distances.get)
        test_row[label_row] = closest_centroid

        city_distances = {}

        for train_row in train:
            if train_row[label_row] == test_row[label_row]:
                city_distances[train_row[0]] = get_distance(train_row, test_row)

        closest_city = min(city_distances, key=city_distances.get)
        output.append([test_row[0],closest_city])

    with open('k_means_pred.csv', 'w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)

        for row in output:
            writer.writerow(row)

    print("Prediction written to k_means_pred.csv")


assign_closest_city()
# Out:
# Iteration 4
# Training written to k_means.csv
# Prediction written to k_means_pred.csv

# %%
linkage_matrix = sch.linkage(df, method='complete') 
plt.figure(figsize=(10, 5))
sch.dendrogram(linkage_matrix, labels=df.index)
plt.title("Dendrogram (Complete)")
plt.xlabel("City index")
plt.ylabel("Distance")
plt.show()

# %% [markdown]
# ### 2. PCA

# %%
# Reuse previous covariance matrix
cov_matrix
# Out:
#                        GDP (USD Billion)  Population (Millions)  \
# GDP (USD Billion)             396.584655              26.685224
# Population (Millions)          26.685224               1.830154
# Unemployment rate (%)         -19.123103              -1.342793
# Average age                    15.087931               1.104931
# Women (%)                       4.243103               0.279138
# Men (%)                        -4.243103              -0.279138
# Budget (USD Billion)           68.613448               4.639603
#
#                        Unemployment rate (%)  Average age  Women (%)  \
# GDP (USD Billion)                 -19.123103    15.087931   4.243103
# Population (Millions)              -1.342793     1.104931   0.279138
# Unemployment rate (%)               8.673333    -5.232184  -0.993103
# Average age                        -5.232184     5.012644   1.224138
# Women (%)                          -0.993103     1.224138   0.603448
# ...

# %%
df_pca = df[["GDP (USD Billion)",  "Population (Millions)"]].values

eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

print(eigenvalues)
# Out:
# [ 4.11889604e+02  1.11629700e+01  1.68403855e+00  4.25028221e-01
#   4.33006308e-02  1.34308565e-02 -1.02825654e-18]

# %%
explained_variance = eigenvalues / np.sum(eigenvalues)

print(explained_variance)
# Out:
# [ 9.68654298e-01  2.62523229e-02  3.96040872e-03  9.99552814e-04
#   1.01831514e-04  3.15857860e-05 -2.41818465e-21]

# %%
print(eigenvectors)
# Out:
# [[ 9.81182086e-01  6.65451229e-02 -5.20753657e-03  2.57759527e-02
#    1.64564883e-01 -7.12765162e-02  2.71527096e-17]
#  [ 6.60509744e-02 -4.01439305e-03  1.14067120e-02 -1.14882968e-01
#   -6.84345913e-01 -7.16912558e-01  1.18929815e-16]
#  [-4.87712459e-02  7.99963372e-01  5.62362358e-01 -2.02041831e-01
#    2.17625601e-02  1.15774174e-02 -4.80152079e-17]
#  [ 3.84082640e-02 -5.70614987e-01  6.22876908e-01 -5.23573368e-01
#    1.04004945e-01  1.26494826e-03  1.39166865e-17]
#  [ 1.07184175e-02 -1.22346802e-01  3.84454579e-01  5.73443194e-01
#   -9.09215484e-02  2.68848221e-03 -7.07106781e-01]
#  [-1.07184175e-02  1.22346802e-01 -3.84454579e-01 -5.73443194e-01
#    9.09215484e-02 -2.68848221e-03 -7.07106781e-01]
#  [ 1.69809849e-01 -8.67710748e-03 -2.24886867e-03 -1.16246885e-01
#   -6.90481700e-01  6.93401723e-01 -1.96632780e-16]]

# %%
pca = PCA()
projected_matrix = pca.fit_transform(df_pca)

projected_df = pd.DataFrame(projected_matrix, columns=[f"PC{i+1}" for i in range(projected_matrix.shape[1])])

# Projected matrix
projected_df
# Out:
#           PC1       PC2
# 0   94.969189  0.072783
# 1   35.393705 -0.538604
# 2   13.719843  0.579135
# 3    8.065338 -0.042616
# 4    1.766126  0.180828
# 5   -1.456866 -0.053304
# 6   -2.561098 -0.079223
# 7   -3.639817  0.274001
# 8   -3.954582  0.064663
# 9   -4.753448  0.108399
# 10  -4.959040  0.032030
# 11  -5.253663  0.122015
# 12  -5.556343  0.092270
# 13  -5.753206  0.145608
# 14  -5.954098  0.139081
# 15  -6.261478  0.039495
# 16  -6.462369  0.032968
# 17  -6.663932  0.016464
# 18  -6.765049  0.003223
# 19  -6.966612 -0.013281
# 20  -7.069744 -0.056454
# 21  -7.267949 -0.023070
# 22  -7.473541 -0.099439
# 23  -7.576672 -0.142612
# 24  -7.671747 -0.066056
# 25  -7.778235 -0.159116
# 26  -7.875995 -0.122470
# 27  -7.978455 -0.155665
# 28  -8.080244 -0.178883
# 29  -8.180018 -0.172169

# %%
error = df_pca - projected_df
error
# Out:
#          PC1       PC2
# 0   8.530811  7.107217
# 1   8.706295  3.108604
# 2   8.680157  1.650865
# 3   8.734662  1.272616
# 4   8.733874  0.849172
# 5   8.756866  0.633304
# 6   8.761098  0.559223
# 7   8.739817  0.485999
# 8   8.754582  0.465337
# 9   8.753448  0.411601
# 10  8.759040  0.397970
# 11  8.753663  0.377985
# 12  8.756343  0.357730
# 13  8.753206  0.344392
# 14  8.754098  0.330919
# 15  8.761478  0.310505
# 16  8.762369  0.297032
# 17  8.763932  0.283536
# 18  8.765049  0.276777
# 19  8.766612  0.263281
# 20  8.769744  0.256454
# 21  8.767949  0.243070
# 22  8.773541  0.229439
# 23  8.776672  0.222612
# 24  8.771747  0.216056
# 25  8.778235  0.209116
# 26  8.775995  0.202470
# 27  8.778455  0.195665
# 28  8.780244  0.188883
# 29  8.780018  0.182169

# %%
pca = PCA(n_components=1)
projection_1d = pca.fit_transform(df_pca)

plt.figure(figsize=(14, 2))
plt.plot(projection_1d, np.zeros_like(projection_1d), 'bo', markersize=5)

for i, city in enumerate(city_names):
    plt.annotate(city, (projection_1d[i], 0), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8)

plt.title('Cities (1 Dimension)')
plt.yticks([]) 
plt.xlabel('PC 1')
plt.grid(True)
plt.show()

# %%
pca = PCA(n_components=2)
projection_2d = pca.fit_transform(df_pca)

plt.figure(figsize=(14, 8))
plt.scatter(projection_2d[:, 0], projection_2d[:, 1], c='blue', marker='o')

for i, city in enumerate(city_names):
    plt.text(projection_2d[i, 0], projection_2d[i, 1], city, fontsize=9, ha='right')

plt.title('Cities (2 Dimensions)')
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. Linear regression

# %%
# Reuse data from k-means

x_values = []
y_values = []

for row in data[1:]:
    x_values.append(float(row[2]))
    y_values.append(float(row[1]))

mean_y = 0
mean_x = 0

for val in y_values:
    mean_y += val

for val in x_values:
    mean_x += val

b0 = 0
b1 = 0
b1_num = 0
b1_den = 0

for row in data[1:]:
    b1_num += (float(row[2])-mean_x) * (float(row[1])-mean_y)
    b1_den += (float(row[2])-mean_x) ** 2

b1 = b1_num / b1_den
b0 = mean_y - (b1 * mean_x)

y_pred = [b0 + b1 * xi for xi in x_values]

plt.figure(figsize=(14, 10))

plt.scatter(x_values, y_values, color='blue', label='Data Points')
plt.plot(x_values, y_pred, color='purple', label=f'Regression Line: y = {b0:.3f} + {b1:.3f}x')

for i, city in enumerate(city_names):
    plt.annotate(city, (x_values[i], y_values[i]), textcoords="offset points", xytext=(0, 10), ha='center', fontsize
              2379,3099,2977,5164,2341,3293,2173,4284,2517,1392,2725,3431,4614,1366,1968,4426,3603,4042,5190,1530,
              3267,2187,3055,3869,4270,1702,2528,2970,4089,2984,3856,3258,4841,1957,4419,1359,2521,2713,2377,5152,
              4080,3097,2145,2979,3251,2383,4074,1506,4848,4246,1734,3063,4622,1350,3407,3635,4410,3894,2946,4883,
              2348,1995,1961,3438,3860,4279,5199,1539,4877,3632,4417,1959,4625,1357,3400,4241,1733,3064,3858,3256,
              2384,4073,1501,3090,2142,2370,5155,4087,2714,2526,4870,3269,2189,3867,1368,4428,1966,2519,1992,4884,
              3893,2941,5018,2833,2659,4768,1814,4902,3915,3129,2666,4591,2454,3586,5215,2030,2202,1487,5027,1641,
              4333,3116,3324,1473,4101,2692,3740,4565,1225,4757,3572,3912,1679,4905,4139,1813,3778,2498,2834,2008,
              4750,3575,2695,3747,4562,3323,1474,4106,1646,4334,3111,2205,1480,5020,5212,2037,2453,3581,2661,4596,
              1825,4759,3924,3118,4933,2802,1489,5029,2668,3588,1442,4130,3315,3127,1670,4302,3543,2491,4766,4554,
              3771,2465,4792,3785,2657,5016,2233,2001,1684,4598,2805,2039,4934,4108,1648,3923,3749,1822,2006,1683,
              5011]

# %%
from scipy.io import loadmat
import glob
import random
import matplotlib.image as img
from PIL import Image

d_name = 'faces/'
X = []
for nfile in  os.listdir(d_name):
    if int(nfile) in train_faces:
        bytes_read = open(os.path.join(d_name,nfile), "rb").read()
        img = Image.frombytes('L', (128,128), bytes_read)
        X.append(np.array(img).flatten())

X = np.array(X)

# %%
def plot_image(data, label="Mean face", ax=None):
    fn_shape = lambda X: X.reshape(128,128)
    fig = None
    if ax is None:
        fig, ax = plt.subplots(1,1, constrained_layout=True)
    ax.imshow(fn_shape(data))
    ax.set_title(label=label)
    return fig,ax

X_mean = X.mean(axis=0)
plot_image(X_mean)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: title={'center': 'Mean face'}>)

# %%
X_center = X - X_mean
plot_image(X_center.mean(axis=0), label = "Centered image")
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: title={'center': 'Centered image'}>)

# %%
pca = PCA(n_components=200)
X_reduced = pca.fit_transform(X_center)
eigenValues = pca.explained_variance_
eigenFaces = pca.components_
# Out:
# To retain 95% of variance: 200

# %%
cum_variance = np.cumsum(pca.explained_variance_ratio_)

components_95 = np.argmax(cum_variance >= 0.95) + 1

print(f"To retain 95% of variance: {components_95}")
# Out:
# To retain 95% of variance: 155

# %%
def reconstruir_imagenes(pca, imagenes_centradas, cara_promedio, n_componentes):
    pca.n_components = n_componentes
    X_reducido = pca.transform(imagenes_centradas)
    X_reconstruido = pca.inverse_transform(X_reducido)
    return X_reconstruido + cara_promedio

# Reconstruir las imágenes con diferentes cantidades de componentes
reconstruido_1 = reconstruir_imagenes(pca, X_center, X_mean, 1)
reconstruido_3 = reconstruir_imagenes(pca, X_center, X_mean, 3)
reconstruido_20 = reconstruir_imagenes(pca, X_center, X_mean, 20)
reconstruido_95 = reconstruir_imagenes(pca, X_center, X_mean, components_95)
reconstruido_99 = reconstruir_imagenes(pca, X_center, X_mean, components_99)

# Visualizar las primeras 5 caras originales y reconstruidas
fig, ejes = plt.subplots(6, 5, figsize=(15, 15))
for i in range(5):
    ejes[0, i].imshow(X[i].reshape(128, 128), cmap='gray')
    ejes[0, i].set_title("Original")
    ejes[0, i].axis('off')
    
    ejes[1, i].imshow(reconstruido_1[i].reshape(128, 128), cmap='gray')
    ejes[1, i].set_title("1 Componente")
    ejes[1, i].axis('off')
    
    ejes[2, i].imshow(reconstruido_3[i].reshape(128, 128), cmap='gray')
    ejes[2, i].set_title("3 Componentes")
    ejes[2, i].axis('off')
    
    ejes[3, i].imshow(reconstruido_20[i].reshape(128, 128), cmap='gray')
    ejes[3, i].set_title("20 Componentes")
    ejes[3, i].axis('off')
    
    ejes[4, i].imshow(reconstruido_95[i].reshape(128, 128), cmap='gray')
    ejes[4, i].set_title(f"{components_95} Componentes (95%)")
    ejes[4, i].axis('off')
    
    ejes[5, i].imshow(reconstruido_99[i].reshape(128, 128), cmap='gray')
    ejes[5, i].set_title(f"{components_99} Componentes (99%)")
    ejes[5, i].axis('off')

plt.show()

# %%
components_99 = np.argmax(cum_variance >= 0.99) + 1
print(f"To retain 99% of variance: {components_99}")
# Out:
# To retain 99% of variance: 1

# %%
eigen_faces = pca.components_
components = 465

fig, axes = plt.subplots(1, num_faces, figsize=(15, 5))  
    
for i in range(num_faces):
    face_reconstructed = np.dot(X_pca_99[i].reshape(1,-1)[:,:components],eigen_faces[:components,:])
    face_image = (X_mean + face_reconstructed.sum(axis=0)).reshape(128, 128)

    ax = axes[i]  
    ax.imshow(face_image)  
    ax.set_title(f"Face {i+1} ({components} components)")  
    ax.set_xlabel("Pixels")
    ax.set_ylabel("Pixels")

plt.tight_layout()
plt.show()

# %%
# TODO: Conclusion?

# %%
X_test = []
for nfile in  os.listdir(d_name):
    if int(nfile) in test_faces:
        bytes_read = open(os.path.join(d_name,nfile), "rb").read()
        img = Image.frombytes('L', (128,128), bytes_read)
        X_test.append(np.array(img).flatten())

X_test = np.array(X_test)
X_test_mean = X_test.mean(axis=0)
X_test_center = X_test - X_test_mean

components = 1
mse_values = []

pca = PCA(n_components=components)
X_pca = pca.fit_transform(X_test_center)
eigen_faces = pca.components_

def get_mse():
    
    for i in range(0, len(X_test)):
        face_reconstructed = np.dot(X_pca[i].reshape(1,-1)[:,:components],eigen_faces[:components,:])
        face_image = (X_test_mean + face_reconstructed.sum(axis=0)).reshape(128, 128)

        mse = np.mean((X_test_center[i] - face_reconstructed) ** 2)
        mse_values.append(mse)
    
get_mse()

with open('faces_pred.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['id','label'])

    for i, value in enumerate(mse_values):
        writer.writerow([test_faces[i], value])

print("Face prediction written to faces_pred.csv")
# Out:
# Face prediction written to faces_pred.csv
